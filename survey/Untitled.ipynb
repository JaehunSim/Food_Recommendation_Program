# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random
from IPython.display import Image
from IPython.lib import passwd

# %%
passwd()
# Out:
# Enter password: ········
# Verify password: ········
# 'sha1:0ee7ca771849:3170729f5fb3e03bedebb45f0f46b1203fcf1855'

# %%
#c = get_config()
#c.NotebookApp.password = 'sha1:0ee7ca771849:3170729f5fb3e03bedebb45f0f46b1203fcf1855'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-d8ae9b0da19e> in <module>()
# ----> 1 c = get_config()
#       2 c.NotebookApp.password = 'sha1:0ee7ca771849:3170729f5fb3e03bedebb45f0f46b1203fcf1855'
#
# NameError: name 'get_config' is not defined

# %%
food_name = "beef"
Image("images/"+food_name+".jpg")
